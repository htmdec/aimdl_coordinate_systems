# %%
import htmdec_formats

# %%
ids = htmdec_formats.IndenterDataset.from_filename("Fiducials.NMD")

# %%
ids.to_df()
# Out:
#       TEST_NUM                              UNIQUEID  \
# 0            0  55c8e648-8be9-41ca-aa1b-a581c4db47f9
# 1            0  55c8e648-8be9-41ca-aa1b-a581c4db47f9
# 2            0  55c8e648-8be9-41ca-aa1b-a581c4db47f9
# 3            0  55c8e648-8be9-41ca-aa1b-a581c4db47f9
# 4            0  55c8e648-8be9-41ca-aa1b-a581c4db47f9
# ...        ...                                   ...
# 1758         4  55c8e648-8be9-41ca-aa1b-a581c4db47f9
# 1759         4  55c8e648-8be9-41ca-aa1b-a581c4db47f9
# 1760         4  55c8e648-8be9-41ca-aa1b-a581c4db47f9
# 1761         4  55c8e648-8be9-41ca-aa1b-a581c4db47f9
# 1762         4  55c8e648-8be9-41ca-aa1b-a581c4db47f9
#
#                               STARTTIME  Displacement  DisplacementAverage  \
# 0     2022-11-27T12:05:51.0520000-06:00     -0.000002            -0.000002
# 1     2022-11-27T12:05:51.0520000-06:00     -0.000002            -0.000002
# 2     2022-11-27T12:05:51.0520000-06:00     -0.000002            -0.000002
# ...

# %%
ids.tests[0].to_df()
# Out:
#       Displacement  DisplacementAverage  DisplacementVolts  DynamicDamping  \
# 0        -0.000002            -0.000002          -0.035962    -2828.174462
# 1        -0.000002            -0.000002          -0.035962    -2828.174449
# 2        -0.000002            -0.000002          -0.036021    -2828.173244
# 3        -0.000002            -0.000002          -0.035950    -2828.174706
# 4        -0.000002            -0.000002          -0.035937    -2828.174964
# ...            ...                  ...                ...             ...
# 2979      0.000004             0.000004           0.070863    -2842.303093
# 2980      0.000004             0.000004           0.070707    -2842.264972
# 2981      0.000004             0.000004           0.070529    -2842.221400
# 2982      0.000004             0.000004           0.070118    -2842.121067
# 2983      0.000003             0.000003           0.053426    -2838.354185
#
# ...

# %%
ids.tests[0].to_df().plot("TimeOnSample", "DynamicDisplacement")
# Out:
# <Axes: xlabel='TimeOnSample'>

# %%
ids.sample_summary.normchanname
# Out:
# 'ShowDepth'

# %%
ids.result_vars["TargetDepth"]
# Out:
# IndenterVar(name='TargetDepth', displayname='Target Depth', formula='', decimals=1, notation='StandardNotation', unitclass='UNIT_CLASS_LENGTH', unittype=2, defaultvalue=5e-06, minimumvalue=2e-08, maximumvalue=1e-05, defaultvaluei50=nan, minimumvaluei50=nan, maximumvaluei50=nan, defaultvaluei1k=nan, minimumvaluei1k=nan, maximumvaluei1k=nan, defaultvaluexp=nan, minimumvaluexp=nan, maximumvaluexp=nan, hasminimum=True, hasmaximum=True, actuatorspecific=True, canedit=True, doublevalue=nan, when=0, reset=True, visibletoui=True, documentation='The targeted maximum Depth.  The experiment will stop loading at this point or if the maximum Target Load is reached.', stringvalue='', accumulator=array([3.e-06, 3.e-06, 3.e-06, 3.e-06, 3.e-06]), statistics=array([3.e-06, 0.e+00, 3.e-06, 0.e+00, 0.e+00]))
